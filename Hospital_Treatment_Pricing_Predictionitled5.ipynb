# %% [markdown]
# <a href="https://colab.research.google.com/github/saronbantte/Data-Science-project-with-python/blob/main/Hospital_Treatment_Pricing_Predictionitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/Package Pricing at Mission Hospital - Data Supplement.csv')

# %%
data.head()
# Out:
#    SL.   AGE GENDER  MALE MARITAL STATUS  UNMARRIED KEY COMPLAINTS -CODE  \
# 0    1  58.0      M     0        MARRIED          0         other- heart
# 1    2  59.0      M     0        MARRIED          0              CAD-DVD
# 2    3  82.0      M     0        MARRIED          0              CAD-TVD
# 3    4  46.0      M     0        MARRIED          0              CAD-DVD
# 4    5  60.0      M     0        MARRIED          0              CAD-DVD
#
#    ACHD  CAD-DVD  CAD-SVD  ...  TYPE OF ADMSN  ELECTIVE  \
# 0     0        0        0  ...      EMERGENCY         0
# 1     0        1        0  ...      EMERGENCY         0
# 2     0        0        0  ...       ELECTIVE         1
# 3     0        1        0  ...      EMERGENCY         0
# 4     0        1        0  ...      EMERGENCY         0
#
#    TOTAL COST TO HOSPITAL   Ln(Total Cost)  TOTAL LENGTH OF STAY  \
# 0                 660293.0       13.400439                    25
# ...
